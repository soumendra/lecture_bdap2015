# %% [markdown]
# Please fill up the following
# * **Student Name:** Abhijit Khuperkar
# * **Student ID:** 10150121
# * **Student Email ID:** abhijit.bdapm10150121@spjain.org
# * **Student GitHub Repo:** https://github.com/akhuperkar

# %% [markdown]
# ## The Assignment
# 1. Write a blog post on how to use **OR** operator for find queries in mongodb.
# 2. Feed negative and positive tweets to the classification function for training. (using the Sentiment140 dataset)
# 3. Crawl all followers of ***naveen_odisha***, Odisha CM (note: you'll have to pay attention to rate limiting)
# 4. Crawl all followers of SRK. How can you calculate if this is feasible or not? (show the math)
# 5. Predict the sentiment of tweets by followers of ***naveen_odisha***

# %% [markdown]
# ### Q1. Write a blog post on how to use **OR** operator for find queries in mongodb.

# %% [markdown]
# #### Is it TRUE or FALSE?
# This type of conditional assessment is often used in programming. The logical operators evaluate boolean conditions of a query expression. The logical operators like OR, AND, NOT join two or more clauses of a query expressions and return a single logical value of either TRUE or FALSE.
#
# It is no different in MongoDB query. A MongoDB query targets a specific collection of documents. Queries specify criteria, or conditions, that identify the documents MongoDB returns to the clients. MongoDB query specifies the criteria and conditions using the following logical operators within the [db.collection.find()](https://docs.mongodb.org/manual/reference/method/db.collection.find/#db.collection.find) method to receive the matching documents.
#
# 1. `$OR`: Returns all documents that match either conditions of the conditional clauses
# 2. `$AND`: Returns all documents that match all conditions of clauses
# 3. `$NOT`: Returns documents that do not match the query condition
# 4. `$NOR`: Returns all documents that fail to match either conditional clauses
#
# #### The OR operator
# Using the `$OR` operator, you can specify a query that joins each clause with a logical OR so that the query selects the documents in the collection that match at least one condition. In syntaxical language, the `$OR` operator performs a logical OR operation on two or more `<expressions>` and selects the documents that satisfy at least one of the `<expressions>`. This is expressed as the following query syntax:
#
# `{ $or: [ { <expression1> }, { <expression2> },..., { <expressionN> } ] }`
#
# In the below example, the query will select all documents in the inventory collection where either the quantity field value is less than (`$lt`) 20 or the price field value equals 10.
#
# `db.inventory.find( { $or: [ { quantity: { $lt: 20 } }, { price: 10 } ] } )`
#
# With additional clauses, you can specify precise conditions. In the below example, the compound query selects all documents in the collection where the value of the *type* field is *'food'* and *either* the *qty* has a value greater than (`$gt`) 100 or the value of the *price* field is less than (`$lt`) 9.95:
#
# `db.inventory.find(
#    {
#      type: 'food',
#      $or: [ { qty: { $gt: 100 } }, { price: { $lt: 9.95 } } ]
#    }
# )`
#
# When evaluating the clauses in the `$or` expression, MongoDB either performs a collection scan or, if all the clauses are supported by indexes, MongoDB performs index scans. The index scan is required when `$or` is used with `$text` and sort() operations. This change was introduced in the 2.6 version of MongoDB.
#
# To conclude, the `$OR` operator helps user to receive the output satisfying at least one of many conditional clauses in the MongoDB query expression.

# %% [markdown]
# ### Q2. Feed negative and positive tweets to the classification function for training. (using the Sentiment140 dataset)

# %%
import csv
import re, math, collections, itertools, os
import nltk, nltk.classify.util, nltk.metrics
from nltk.classify import NaiveBayesClassifier
from nltk.metrics import BigramAssocMeasures
from nltk.probability import FreqDist, ConditionalFreqDist
from nltk.metrics import accuracy, precision, recall

#this function takes a feature selection mechanism and returns its performance in a variety of metrics
def evaluate_features(feature_select):
	posFeaturesTrain = []
	negFeaturesTrain = []

	#breaks up the sentences into lists of individual words and appends 'pos' or 'neg' after each list
	with open("/home/abhijit/Documents/TwitterAnalysis/trainingandtestdata/training.1600000.processed.noemoticon.csv", 'r') as TrainFile:
		TrainTweets = csv.reader(TrainFile)
		for i in TrainTweets:
			if i[0]=="4":
				posWordsTrain = re.findall(r"[\w']+|[.,!?;]", i[4].rstrip())
				posWordsTrain = [feature_select(posWordsTrain), 'pos']
				posFeaturesTrain.append(posWordsTrain)
			elif i[0]=="0":
				negWordsTrain = re.findall(r"[\w']+|[.,!?;]", i[4].rstrip())
				negWordsTrain = [feature_select(negWordsTrain), 'neg']
				negFeaturesTrain.append(negWordsTrain)

	trainFeatures = posFeaturesTrain + negFeaturesTrain
	
	#selects the features to be used for testing
	posFeaturesTest = []
	negFeaturesTest = []
	with open("/home/abhijit/Documents/TwitterAnalysis/trainingandtestdata/testdata.manual.2009.06.14.csv", 'r') as TestFile:
		TestTweets = csv.reader(TestFile)
		for j in TestTweets:
			if j[0]=="4":
				posWordsTest = re.findall(r"[\w']+|[.,!?;]", j[4].rstrip())
				posWordsTest = [feature_select(posWordsTest), 'pos']
				posFeaturesTest.append(posWordsTest)
			elif j[0]=="0":
				negWordsTest = re.findall(r"[\w']+|[.,!?;]", j[4].rstrip())
				negWordsTest = [feature_select(negWordsTest), 'neg']
				negFeaturesTest.append(negWordsTest)
	
	testFeatures = posFeaturesTest + negFeaturesTest
	
	#trains a Naive Bayes Classifier
	classifier = NaiveBayesClassifier.train(trainFeatures)

	#initiates referenceSets and testSets
	referenceSets = collections.defaultdict(set)
	testSets = collections.defaultdict(set)	

	#puts correctly labeled sentences in referenceSets and the predictively labeled version in testsets
	for k, (features, label) in enumerate(testFeatures):
		referenceSets[label].add(k)
		predicted = classifier.classify(features)
		testSets[predicted].add(k)	

	#prints metrics to show how well the feature selection did
	print 'train on %d instances, test on %d instances' % (len(trainFeatures), len(testFeatures))
	print 'accuracy:', nltk.classify.util.accuracy(classifier, testFeatures)
	#print 'pos precision:', nltk.metrics.precision(referenceSets['pos'], testSets['pos'])
	#print 'pos recall:', nltk.metrics.recall(referenceSets['pos'], testSets['pos'])
	#print 'neg precision:', nltk.metrics.precision(referenceSets['neg'], testSets['neg'])
	#print 'neg recall:', nltk.metrics.recall(referenceSets['neg'], testSets['neg'])
	classifier.show_most_informative_features(10)

#creates a feature selection mechanism that uses all words
def make_full_dict(words):
	return dict([(word, True) for word in words])

#tries using all words as the feature selection mechanism
print 'using all words as features'
evaluate_features(make_full_dict)

#scores words based on chi-squared test to show information gain
def create_word_scores():
	#creates lists of all positive and negative words
	posWords = []
	negWords = []
	with open("/home/abhijit/Documents/TwitterAnalysis/trainingandtestdata/training.1600000.processed.noemoticon.csv", 'r') as TrainFile:
		TrainTweets = csv.reader(TrainFile)
		for i in TrainTweets:
			if i[0]=="4":
				posWord = re.findall(r"[\w']+|[.,!?;]", i[4].rstrip())
				posWords.append(posWord)
			elif i[0]=="0":
				negWord = re.findall(r"[\w']+|[.,!?;]", i[4].rstrip())
				negWords.append(negWord)
	posWords = list(itertools.chain(*posWords))
	negWords = list(itertools.chain(*negWords))

	#build frequency distibution of all words and then frequency distributions of words within positive and negative labels
	word_fd = FreqDist()
	cond_word_fd = ConditionalFreqDist()
	for word in posWords:
		word_fd[word.lower()] += 1
		cond_word_fd['pos'][word.lower()] += 1
	for word in negWords:
		word_fd[word.lower()] += 1
		cond_word_fd['neg'][word.lower()] += 1

	#finds the number of positive and negative words, as well as the total number of words
	pos_word_count = cond_word_fd['pos'].N()
	neg_word_count = cond_word_fd['neg'].N()
	total_word_count = pos_word_count + neg_word_count

	#builds dictionary of word scores based on chi-squared test
	word_scores = {}
	for word, freq in word_fd.iteritems():
		pos_score = BigramAssocMeasures.chi_sq(cond_word_fd['pos'][word], (freq, pos_word_count), total_word_count)
		neg_score = BigramAssocMeasures.chi_sq(cond_word_fd['neg'][word], (freq, neg_word_count), total_word_count)
		word_scores[word] = pos_score + neg_score

	return word_scores

#finds word scores
word_scores = create_word_scores()

#finds the best 'number' words based on word scores
def find_best_words(word_scores, number):
	best_vals = sorted(word_scores.iteritems(), key=lambda (w, s): s, reverse=True)[:number]
	best_words = set([w for w, s in best_vals])
	return best_words

#creates feature selection mechanism that only uses best words
def best_word_features(words):
	return dict([(word, True) for word in words if word in best_words])

#numbers of features to select
numbers_to_test = [100, 1000, 10000]
#tries the best_word_features mechanism with each of the numbers_to_test of features
for num in numbers_to_test:
	print 'evaluating best %d word features' % (num)
	best_words = find_best_words(word_scores, num)
	evaluate_features(best_word_features)
# Out:
# using all words as features
# train on 1600000 instances, test on 359 instances
# accuracy: 0.557103064067
# Most Informative Features
#                   wowlew = True              neg : pos    =     84.2 : 1.0
#                  dogzero = True              pos : neg    =     63.0 : 1.0
#                   nsane8 = True              pos : neg    =     54.3 : 1.0
#                  snedwan = True              pos : neg    =     52.3 : 1.0
#               Angel42579 = True              pos : neg    =     49.7 : 1.0
#                    RGM77 = True              pos : neg    =     43.0 : 1.0
#             angelaxjonas = True              pos : neg    =     42.3 : 1.0
#             Cuttersftbll = True              pos : neg    =     42.3 : 1.0
#                DarkPiano = True              pos : neg    =     42.1 : 1.0
#              GlitzyGloss = True              pos : neg    =     41.0 : 1.0
# evaluating best 100 word features
# train on 1600000 instances, test on 359 instances
# accuracy: 0.506963788301
# Most Informative Features
#                   wowlew = True              neg : pos    =     84.2 : 1.0
#                  dogzero = True              pos : neg    =     63.0 : 1.0
#                   nsane8 = True              pos : neg    =     54.3 : 1.0
#                  snedwan = True              pos : neg    =     52.3 : 1.0
#             original_one = True              pos : neg    =     39.3 : 1.0
#           tallivansunder = True              pos : neg    =     37.9 : 1.0
#               syarif_m2e = True              pos : neg    =     34.2 : 1.0
#              effingcards = True              pos : neg    =     29.3 : 1.0
#              chiniehdiaz = True              pos : neg    =     27.4 : 1.0
#                   keza34 = True              pos : neg    =     24.9 : 1.0
# evaluating best 1000 word features
# train on 1600000 instances, test on 359 instances
# accuracy: 0.506963788301
# Most Informative Features
#                   wowlew = True              neg : pos    =     84.2 : 1.0
#                  dogzero = True              pos : neg    =     63.0 : 1.0
#                   nsane8 = True              pos : neg    =     54.3 : 1.0
#                  snedwan = True              pos : neg    =     52.3 : 1.0
#             angelaxjonas = True              pos : neg    =     42.3 : 1.0
#             original_one = True              pos : neg    =     39.3 : 1.0
#           tallivansunder = True              pos : neg    =     37.9 : 1.0
#          spahkleprincess = True              pos : neg    =     37.0 : 1.0
#                 tezzer57 = True              pos : neg    =     37.0 : 1.0
#                zaneology = True              pos : neg    =     36.3 : 1.0
# evaluating best 10000 word features
# train on 1600000 instances, test on 359 instances
# accuracy: 0.506963788301
# Most Informative Features
#                   wowlew = True              neg : pos    =     84.2 : 1.0
#                  dogzero = True              pos : neg    =     63.0 : 1.0
#                   nsane8 = True              pos : neg    =     54.3 : 1.0
#                  snedwan = True              pos : neg    =     52.3 : 1.0
#             angelaxjonas = True              pos : neg    =     42.3 : 1.0
#             original_one = True              pos : neg    =     39.3 : 1.0
#           tallivansunder = True              pos : neg    =     37.9 : 1.0
#          spahkleprincess = True              pos : neg    =     37.0 : 1.0
#                 tezzer57 = True              pos : neg    =     37.0 : 1.0
#                zaneology = True              pos : neg    =     36.3 : 1.0

# %% [markdown]
# ### Q3. Crawl all followers of ***naveen_odisha***, Odisha CM (note: you'll have to pay attention to rate limiting)

# %%
import os
import time
import tweepy
import csv
import numpy as np
import pandas as pd

TWITTER_CONSUMER_KEY = os.environ["TWITTER_CONSUMER_KEY"]
TWITTER_CONSUMER_SECRET = os.environ["TWITTER_CONSUMER_SECRET"]
TWITTER_ACCESS_TOKEN = os.environ["TWITTER_ACCESS_TOKEN"]
TWITTER_ACCESS_TOKEN_SECRET = os.environ["TWITTER_ACCESS_TOKEN_SECRET"]

auth = tweepy.OAuthHandler(TWITTER_CONSUMER_KEY, TWITTER_CONSUMER_SECRET)
auth.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

if(api.verify_credentials):
    print 'Sucessfully logged in \n'

def limit_handled(cursor):
    while True:
        try:
            yield cursor.next()
        except tweepy.RateLimitError:
            time.sleep(15 * 60)

for follower in limit_handled(tweepy.Cursor(api.followers, screen_name="naveen_odisha").items()):
    print("User: {0} \t\t Name: {1} \t\t Number of tweets: {2}".format(follower.screen_name.encode("utf-8"), 
                                                                          follower.name.encode("utf-8"), 
                                                                      follower.statuses_count))
    
#wrote below lines to save results of follower info in a csv file. This did not work.
#f = pd.DataFrame()
#sn = []
#un = []
#sc = []

#for follower in limit_handled(tweepy.Cursor(api.followers, screen_name="naveen_odisha").items()):
#    sn.append(follower.screen_name.encode("utf-8"))
#    print(sn)

#    un.append(follower.name.encode("utf-8"))
#    sc.append(follower.statuses_count)
#    x = np.array((sn,un,sc))
#    z = x.transpose()

#f = pd.DataFrame(z)
#f.head()
#f.to_csv('/home/abhijit/Documents/GitProjects/bdap2015/Hands-on: Twitter Sentiment Mining/nofollwers_abhijitk.csv')
# Out:
# Sucessfully logged in
#
# User: kapil_kambe 		 Name: Kapil Kambe 		 Number of tweets: 0
# User: ManojaMahani 		 Name: manoja kumar mahani 		 Number of tweets: 4
# User: priyadarshidash 		 Name: Priyadarshi 		 Number of tweets: 10
# User: RajuKha75715155 		 Name: Raju Khan 		 Number of tweets: 1
# User: lokanathdas1 		 Name: lokanath das 		 Number of tweets: 8
# User: BalGyana 		 Name: Gyana Ranjan Bal 		 Number of tweets: 3
# User: AKASHPATTANAIK1 		 Name: AKASH PATTANAIK 		 Number of tweets: 33
# User: skrashidali3 		 Name: skrashidali 		 Number of tweets: 0
# User: PrasmitJagadala 		 Name: PRASMIT JAGADALA 		 Number of tweets: 0
# User: sambhunsahoo1 		 Name: sambhunath sahoo 		 Number of tweets: 0
# User: bbsrdinesh 		 Name: Dinesh Kumar Patel 		 Number of tweets: 0
# User: bapumishra506 		 Name: chandrashekhar mishr 		 Number of tweets: 0
# User: SSwayam_Sarthak 		 Name: Swayam Sarthak 		 Number of tweets: 1
# User: ambika709 		 Name: Ambika Pr. Kanungo 		 Number of tweets: 10
# User: sumitbunty4 		 Name: sumitmohanty 		 Number of tweets: 0
# User: GurudevSahoo 		 Name: Gurudev sahoo 		 Number of tweets: 0
# User: sshreetam1 		 Name: shreetam senapati 		 Number of tweets: 1
# User: SharatchandraH 		 Name: SharatchandraH ABVP 		 Number of tweets: 0
# User: shovanmohanty99 		 Name: shovan mohanty 		 Number of tweets: 4
# User: PunyaslokGuru 		 Name: Punyaslok Guru 		 Number of tweets: 1
# User: prasantabaral1 		 Name: prasanta baral 		 Number of tweets: 339
# User: GhadaiSusanta 		 Name: susanta ghadai 		 Number of tweets: 0
# User: r_rkpattanaik 		 Name: R K PATNAIK 		 Number of tweets: 0
# User: chiranjibimish5 		 Name: chandrasekharmishra 		 Number of tweets: 19
# User: GnomeBaba 		 Name: Baba Gnome 		 Number of tweets: 76
# User: Ashikkumar489 		 Name: Ashik Kumar 		 Number of tweets: 0
# User: Biswaranjan82af 		 Name: Biswaranjan Samal 		 Number of tweets: 3
# User: anjanch34587522 		 Name: anjan chakraborty 		 Number of tweets: 0
# User: sagarsuman3mar1 		 Name: Sagar Suman 		 Number of tweets: 1
# User: PujaBodhak3 		 Name: Puja Bodhak 		 Number of tweets: 1
# User: HThapps 		 Name: HTH 		 Number of tweets: 127
# User: SBR1209 		 Name: Subhendu Bhusan 		 Number of tweets: 1
# User: sourav943775565 		 Name: SAURAV SUNDAR DEY 		 Number of tweets: 0
# User: SumanSeth15 		 Name: Suman Seth 		 Number of tweets: 0
# User: ctistudio 		 Name: INCUBATORCTS 		 Number of tweets: 87
# User: maman_nayak 		 Name: hiranmayee 		 Number of tweets: 3
# User: manojku39947225 		 Name: manojkumarbehera 		 Number of tweets: 0
# User: simdegaalok 		 Name: alok patel... 		 Number of tweets: 258
# User: uma7090 		 Name: uma sankar mahapatro 		 Number of tweets: 0
# User: hemant_lenka 		 Name: Hemant Lenka 		 Number of tweets: 7
# User: 59317dabc1d2478 		 Name: Gourab Toppo 		 Number of tweets: 0
# User: kamalje79100400 		 Name: kamal jeet 		 Number of tweets: 1
# User: rama70chandra 		 Name: ramachandrabehera 		 Number of tweets: 0
# User: samloveme123 		 Name: Ramakrushna Tripathy 		 Number of tweets: 0
# User: Mr_PERFECT61 		 Name: Srikant panigrahi 		 Number of tweets: 82
# User: MdZafer7 		 Name: Md Zafer 		 Number of tweets: 0
# User: TwitSurajit7044 		 Name: SURAJIT 		 Number of tweets: 0
# User: Gendeba 		 Name: DEBABRATA MISRA 		 Number of tweets: 45
# User: Bikashagrawal4 		 Name: Bikash Agrawal 		 Number of tweets: 0
# User: Manasranjan1221 		 Name: Manas Ranjan 		 Number of tweets: 0
# User: shitichandan 		 Name: Shitikantha parhi 		 Number of tweets: 0
# User: ved_panchal 		 Name: ved parkash panchal 		 Number of tweets: 117
# User: acsharma57 		 Name: A C SHARMA 		 Number of tweets: 0
# User: PurnenduChaira 		 Name: Purnendu Chaira 		 Number of tweets: 0
# User: SpandanM7 		 Name: Spandan Mohapatra 		 Number of tweets: 2
# User: ParamanandaDal1 		 Name: Paramananda Dalai 		 Number of tweets: 0
# User: Smrutir39421166 		 Name: Smruti ranjan das 		 Number of tweets: 0
# User: bmp5757537 		 Name: Basant Patra 		 Number of tweets: 0
# User: Sahoo24499698 		 Name: Sahoo 		 Number of tweets: 5
# User: amit_bhatra 		 Name: amit bhatra 		 Number of tweets: 1
# User: sunetradas92 		 Name: Sunetra Das 		 Number of tweets: 0
# User: bkpanda05 		 Name: Balakrishna Panda 		 Number of tweets: 0
# User: sarojmunda5161 		 Name: sarojmunda 		 Number of tweets: 2
# User: NBishalChoudhu1 		 Name: N Bishal Choudhury 		 Number of tweets: 0
# User: arungoud643 		 Name: Arun goud 		 Number of tweets: 1
# User: bcpatra 		 Name: BRUNDABAN CH PATRA 		 Number of tweets: 8
# User: blazeblizzardor 		 Name: Manish Panda 		 Number of tweets: 0
# User: snehasis_sahoo 		 Name: Snehasis Sahoo 		 Number of tweets: 0
# User: darlingbhanu55 		 Name: DarlingBhanu 		 Number of tweets: 1
# User: AbhinnaAshutosh 		 Name: Abhinna Ashutosh 		 Number of tweets: 1
# User: swastiksunu 		 Name: Swastik Panigrahi 		 Number of tweets: 0
# User: Tofan25610314 		 Name: Tofan 		 Number of tweets: 0
# User: dashchandan3383 		 Name: Sangram Keshari 		 Number of tweets: 1
# User: Kunu109 		 Name: Ricky 		 Number of tweets: 1
# User: 304Alok 		 Name: alok ranjan das 		 Number of tweets: 1
# User: sipu_rock 		 Name: Chakan Majhi 		 Number of tweets: 1
# User: SUNILMA03222261 		 Name: SUNIL MAHARANA 		 Number of tweets: 0
# User: Kunu104 		 Name: Kunu 		 Number of tweets: 9
# User: SaniaRath 		 Name: Sania Rath 		 Number of tweets: 0
# User: rituridinghood 		 Name: Perfect 		 Number of tweets: 4120
# User: DebabrataRout11 		 Name: Debabrata Rout 		 Number of tweets: 1
# User: ChandankrMitra1 		 Name: Chandan kr Mitra 		 Number of tweets: 1
# User: Subhaji28631649 		 Name: Subhajit Saha 		 Number of tweets: 0
# User: rameshmohanty43 		 Name: Ramesh mohanty 		 Number of tweets: 0
# User: AryaKumari1 		 Name: Arya Kumari 		 Number of tweets: 0
# User: buttlerjay6 		 Name: Madhura Rangan 		 Number of tweets: 0
# User: jaybuttler61 		 Name: Tasha Deshmukh 		 Number of tweets: 0
# User: BharatiMishra5 		 Name: Bharati Mishra 		 Number of tweets: 0
# User: hse_aneek 		 Name: Hse Aneek 		 Number of tweets: 2686
# User: Behera712J 		 Name: jyoti ranjan Behera 		 Number of tweets: 0
# User: PMohanty01 		 Name: prabhas Mohanty 		 Number of tweets: 14
# User: sknarayanjain 		 Name: keshab narayan jain 		 Number of tweets: 14
# User: jaybuttlerweb 		 Name: alka nanda 		 Number of tweets: 0
# User: orissacabsserv1 		 Name: orissacabs 		 Number of tweets: 194
# User: AbhinabMandal 		 Name: abhinab mandal 		 Number of tweets: 1
# User: jaybuttler856 		 Name: Sonali Priyadarshini 		 Number of tweets: 1
# User: Surajthakur2009 		 Name: Sumit thakur 		 Number of tweets: 355
# User: desai_abha 		 Name: abha desai 		 Number of tweets: 0
# User: smund456 		 Name: sarbeswar Mund 		 Number of tweets: 0
# User: JotheVallal 		 Name: jothe vallal 		 Number of tweets: 462
# User: saumyaparida40 		 Name: saumya ranjan parida 		 Number of tweets: 0
# User: srikantpatro2 		 Name: srikant patro 		 Number of tweets: 5
# User: DebsShakti 		 Name: Debasmit Shaktiman 		 Number of tweets: 217
# User: SrivastaShubham 		 Name: Shubham Raj srivasta 		 Number of tweets: 3
# User: nirmalniri 		 Name: Nirmal Dash 		 Number of tweets: 0
# User: GowdaSeo 		 Name: kamladevi gowda 		 Number of tweets: 2
# User: VeronicaBiswal 		 Name: Veronica Biswal 		 Number of tweets: 1
# User: Mdasgar52295233 		 Name: Mdasgar 		 Number of tweets: 1
# User: cadd_house 		 Name: CaddHouse 		 Number of tweets: 4
# User: bkarpan 		 Name: b k arpan subhashis 		 Number of tweets: 23
# User: drarpita92 		 Name: Dr Arpita 		 Number of tweets: 9626
# User: BapatIbha 		 Name: Ibha Bapat 		 Number of tweets: 0
# User: sudhirkumarBe13 		 Name: sudhir kumar Behera 		 Number of tweets: 0
# User: gauravg46603253 		 Name: gaurav gupta 		 Number of tweets: 1
# User: OpgcDas 		 Name: IPSIT DAS 		 Number of tweets: 1
# User: sethi_lokanath 		 Name: Lokanath Sethi 		 Number of tweets: 0
# User: prabhat768 		 Name: Prabhat Mukharjee 		 Number of tweets: 1
# User: krlenka2013 		 Name: Keerti RL 		 Number of tweets: 92
# User: nikusamal 		 Name: priyabrat Samal 		 Number of tweets: 7
# User: VikasGandhiVG 		 Name: Vikas Gandhi 		 Number of tweets: 1
# User: sunitasahooo432 		 Name: Sunita Sahoo 		 Number of tweets: 1
# User: pankajat501 		 Name: pankaj sahani 		 Number of tweets: 0
# User: sougata105178 		 Name: Sougata Sinha Roy 		 Number of tweets: 4
# User: Dipakda05078582 		 Name: Dipak das 		 Number of tweets: 0
# User: ruparathodseli1 		 Name: Rupa Rathod 		 Number of tweets: 1
# User: pradeepagarwl 		 Name: pradeep 		 Number of tweets: 170
# User: eparimadhu1 		 Name: eparimadhu 		 Number of tweets: 0
# User: Pujamon49234903 		 Name: Puja mondal 		 Number of tweets: 0
# User: soumya2016 		 Name: Soumya Mohanty 		 Number of tweets: 3
# User: sandyjoins 		 Name: sandeep pandey 		 Number of tweets: 1
# User: iOmswaroop 		 Name: om swaroop sahu 		 Number of tweets: 152
# User: shikhapriyadar5 		 Name: shikha priyadarshni 		 Number of tweets: 0
# User: shikhapriyadar8 		 Name: shikha priyadarshni 		 Number of tweets: 0
# User: gopald09 		 Name: Gopal Krishna Dila 		 Number of tweets: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-4d5faecc7b42> in <module>()
#      25             time.sleep(15 * 60)
#      26
# ---> 27 for follower in limit_handled(tweepy.Cursor(api.followers, screen_name="naveen_odisha").items()):
#      28     print("User: {0} \t\t Name: {1} \t\t Number of tweets: {2}".format(follower.screen_name.encode("utf-8"),
#      29                                                                           follower.name.encode("utf-8"),
#
# <ipython-input-1-4d5faecc7b42> in limit_handled(cursor)
#      23             yield cursor.next()
#      24         except tweepy.RateLimitError:
# ---> 25             time.sleep(15 * 60)
#      26
#      27 for follower in limit_handled(tweepy.Cursor(api.followers, screen_name="naveen_odisha").items()):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Q4. Crawl all followers of SRK. How can you calculate if this is feasible or not? (show the math)

# %% [markdown]
# #### The Math
# Twitter GET followers/ids method in API 1.1 version has the Rate Limit of 15 requests per 15-minutes window, i.e. about 60 requests per hour. Further, the method returns maximum 5000 ids per request. Given the rate limit, you have to issue more requests to get all the followers of popular users.
#
# SRK has a total 17.3M followers. With no interruptions, it will take about 2.4 days (=17300000/(5000x60x24)) to load SRK's all followers.

# %%
import os
import time
import tweepy

TWITTER_CONSUMER_KEY = os.environ["TWITTER_CONSUMER_KEY"]
TWITTER_CONSUMER_SECRET = os.environ["TWITTER_CONSUMER_SECRET"]
TWITTER_ACCESS_TOKEN = os.environ["TWITTER_ACCESS_TOKEN"]
TWITTER_ACCESS_TOKEN_SECRET = os.environ["TWITTER_ACCESS_TOKEN_SECRET"]

auth = tweepy.OAuthHandler(TWITTER_CONSUMER_KEY, TWITTER_CONSUMER_SECRET)
auth.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

if(api.verify_credentials):
    print 'Sucessfully logged in \n'

def limit_handled(cursor):
    while True:
        try:
            yield cursor.next()
        except tweepy.RateLimitError:
            time.sleep(15 * 60)

for follower in limit_handled(tweepy.Cursor(api.followers, screen_name="iamsrk").items()):
    print("User: {0} \t\t Name: {1} \t\t Number of tweets: {2}".format(follower.screen_name.encode("utf-8"), 
                                                                          follower.name.encode("utf-8"), 
                                                                      follower.statuses_count))
# Out:
# Sucessfully logged in
#
# User: lalajr_ 		 Name: Lala Jr. 		 Number of tweets: 0
# User: khawerali18 		 Name: khawer ali 		 Number of tweets: 3
# User: Umesha959106357 		 Name: Umesha 		 Number of tweets: 0
# User: karankrsp75 		 Name: Rajesh kumar Das 		 Number of tweets: 1
# User: rish_thakkar 		 Name: Rish Thakkar 		 Number of tweets: 0
# User: djtstar20 		 Name: Sanchit Krishan 		 Number of tweets: 1
# User: asishdebnath11 		 Name: asish debnath 		 Number of tweets: 0
# User: Tisul_AS 		 Name: Tisul tgh bertenang 		 Number of tweets: 2617
# User: goldenryu2000 		 Name: Nishant Sharma 		 Number of tweets: 0
# User: CornelaTombuku 		 Name: Cornela Tombuku 		 Number of tweets: 0
# User: 31bfd6b98b0b465 		 Name: JUNED 		 Number of tweets: 0
# User: uouououo1811 		 Name: +9647708134488 		 Number of tweets: 0
# User: sk19882 		 Name: suhail khan 		 Number of tweets: 0
# User: rohit7071 		 Name: rohit sharma 		 Number of tweets: 0
# User: TanviChipkar 		 Name: TANVI CHIPKAR 		 Number of tweets: 0
# User: brzoskvinoid 		 Name: Kaja Urbaniuk 		 Number of tweets: 0
# User: JaishreePrajap1 		 Name: Jaishree Prajapati J 		 Number of tweets: 0
# User: Sun_srtroke 		 Name: Sun Stroke 		 Number of tweets: 0
# User: ksShekhawat11 		 Name: केसरिया ks.Shekhawat 		 Number of tweets: 0
# User: AriefKh34388361 		 Name: MD. ARIFUL ISLAM 		 Number of tweets: 0
# User: ghoshchandan19 		 Name: chandan 		 Number of tweets: 0
# User: anggit_saja 		 Name: anggit 		 Number of tweets: 0
# User: nangker_hum 		 Name: nangker hum 		 Number of tweets: 0
# User: eti398489 		 Name: Eti Rohaetie 		 Number of tweets: 0
# User: Sajalchand5 		 Name: Sajal chand 		 Number of tweets: 0
# User: noandita 		 Name: Nandita Ghosh 		 Number of tweets: 0
# User: PawanSh59953349 		 Name: Pawan Sharma 		 Number of tweets: 0
# User: M_Arief333 		 Name: M ARIEF 		 Number of tweets: 0
# User: L2jlk_SHOJ 		 Name: L2jlk_shoj 		 Number of tweets: 0
# User: 2009rmm 		 Name: ramy 		 Number of tweets: 0
# User: samsul77712083 		 Name: samsul 		 Number of tweets: 0
# User: Afzalhu87336259 		 Name: Afzal husain 		 Number of tweets: 16
# User: KanuAnupom 		 Name: Anupom Kanu 		 Number of tweets: 0
# User: Amitkum94676543 		 Name: amit arya 		 Number of tweets: 28
# User: altafraza7384 		 Name: Altaf Ansari 		 Number of tweets: 2
# User: rashminfernand4 		 Name: sasindu rashmin 		 Number of tweets: 0
# User: RohitRk5851579 		 Name: Rohit Kumar 		 Number of tweets: 0
# User: Bilal0558 		 Name: Bilal Ahmad 		 Number of tweets: 1
# User: AzZaaz8118 		 Name: frhan turki 		 Number of tweets: 0
# User: LoloNnana 		 Name: Lolo Nnana 		 Number of tweets: 0
# User: pawananimation2 		 Name: pawan kumar singh 		 Number of tweets: 0
# User: Saipras48743871 		 Name: Saiprasad 		 Number of tweets: 0
# User: KapillD 		 Name: kapill deveshh 		 Number of tweets: 0
# User: mmkhan37_khan 		 Name: mohammed khan 		 Number of tweets: 0
# User: KumarSewag 		 Name: Mukesh Kumar Sewag 		 Number of tweets: 3
# User: SLakumi 		 Name: shreelakshmi lakumi 		 Number of tweets: 0
# User: 987sappu 		 Name: aishwarya gupta 		 Number of tweets: 0
# User: fk71404 		 Name: Faisal Khan 		 Number of tweets: 0
# User: BellaAnggriani9 		 Name: Bella Anggriani 		 Number of tweets: 0
# User: krishnayadav203 		 Name: krishna yadav 		 Number of tweets: 0
# User: kiing632 		 Name: king 		 Number of tweets: 0
# User: Tlikhan 		 Name: Muhammad Tufail khan 		 Number of tweets: 0
# User: sameers20508537 		 Name: Sameer Shaikh 		 Number of tweets: 0
# User: Harshva00402205 		 Name: Harshvardhan Singh k 		 Number of tweets: 0
# User: DRxSKVERMA 		 Name: S K. VERMA 		 Number of tweets: 0
# User: reverezayn 		 Name: Noelle. 		 Number of tweets: 3
# User: sajini_ramanan 		 Name: Sajini 		 Number of tweets: 0
# User: azizul_tohin 		 Name: azizul islam tohin 		 Number of tweets: 0
# User: MeenaMantesh 		 Name: mantesh meena 		 Number of tweets: 0
# User: sleman98mo 		 Name: Sleman mo 		 Number of tweets: 0
# User: YaseeN707 		 Name: yaseeN 		 Number of tweets: 0
# User: Shivam82551959 		 Name: Shivam 		 Number of tweets: 0
# User: younisabbasi524 		 Name: younis 		 Number of tweets: 0
# User: MsqPy8830rUzzMd 		 Name: نونة الكتلونية‎ 		 Number of tweets: 1
# User: natkare_laxman 		 Name: Laxman Natkare 		 Number of tweets: 0
# User: MSuhatra 		 Name: Suhatra Majumder 		 Number of tweets: 0
# User: rshahjaj525 		 Name: رشا حجاج 		 Number of tweets: 0
# User: iamluxheart 		 Name: Suraz Gaire 		 Number of tweets: 1
# User: atitud 		 Name: Astried Anggraini 		 Number of tweets: 22581
# User: orpitindia1 		 Name: Anirban Mukherjee 		 Number of tweets: 2
# User: rafarre936 		 Name: rahaf 		 Number of tweets: 6
# User: wpthemebuyer 		 Name: wpthemebuyer 		 Number of tweets: 0
# User: Parveshrao4 		 Name: Parveshrao 		 Number of tweets: 0
# User: rahul_yadav007 		 Name: rahul yadav 		 Number of tweets: 0
# User: aghakhursheedk1 		 Name: agha khursheed khan 		 Number of tweets: 2
# User: pranavk40592772 		 Name: pranav kulkarni 		 Number of tweets: 1
# User: hadeel97866123 		 Name: Hadeel Hadeel 		 Number of tweets: 0
# User: m1698z 		 Name: استغفرالله 		 Number of tweets: 10
# User: TarsemSudan 		 Name: TarsemSudan 		 Number of tweets: 1
# User: virdiaman72 		 Name: Aman Virdi 		 Number of tweets: 0
# User: snmzzzqq 		 Name: 100003120522388@face 		 Number of tweets: 0
# User: riri_riridodo 		 Name: riri 		 Number of tweets: 0
# User: tandon7070 		 Name: Rahul Tandon 		 Number of tweets: 0
# User: misbauli80 		 Name: Misbaul Islam 		 Number of tweets: 0
# User: salim_islim 		 Name: Salim Islim 		 Number of tweets: 0
# User: AmmarMushantat 		 Name: ammar mushantat 		 Number of tweets: 0
# User: abo_ali_alaramy 		 Name: عبد العرامي 		 Number of tweets: 0
# User: Masuduiu 		 Name: Masud-Ul-Hasan 		 Number of tweets: 0
# User: HamzaJa23233322 		 Name: Hamza Javed 		 Number of tweets: 4
# User: Rishith27852389 		 Name: Rishi thakur 		 Number of tweets: 2
# User: atultiger2 		 Name: atul tiger 		 Number of tweets: 0
# User: nadia_rafiq7 		 Name: Nadia Rafiq 		 Number of tweets: 0
# User: ReadersPride 		 Name: Readers Pride 		 Number of tweets: 0
# User: mohd_anzoh 		 Name: Anzoh 		 Number of tweets: 1
# User: royalanurag567 		 Name: Anurag Pandey 		 Number of tweets: 0
# User: priyama77145212 		 Name: Priya Maheshwari 		 Number of tweets: 0
# User: maryadi_cebong 		 Name: Maryadi Cebong 		 Number of tweets: 0
# User: Anwarlangah2 		 Name: Anwarlangah 		 Number of tweets: 0
# User: bhaskarkumarsa 		 Name: bhaskarkumar sarkar 		 Number of tweets: 0
# User: mamankryadi 		 Name: mamankryadi 		 Number of tweets: 0
# User: TanjilaAzad 		 Name: Tanjila Azad 		 Number of tweets: 0
# User: Seso_khawaldeh 		 Name: Seso_khawaldeh 		 Number of tweets: 0
# User: SowrovKumar 		 Name: sree sowrov kumar sa 		 Number of tweets: 1
# User: Vikramk82925567 		 Name: Vikram kumawat 		 Number of tweets: 0
# User: pipilikar 		 Name: nibrite 		 Number of tweets: 12
# User: nareshrochy 		 Name: Naresh Rocky Naresh 		 Number of tweets: 0
# User: hmama48o 		 Name: hmama 		 Number of tweets: 0
# User: santoshvinay1 		 Name: santosh vinay kumar 		 Number of tweets: 1
# User: dheeraj_tuteja 		 Name: Dheeraj Tuteja 		 Number of tweets: 0
# User: Rajeshkathi2 		 Name: Rajeshkathi 		 Number of tweets: 0
# User: vp595049 		 Name: Vishal Pawar 		 Number of tweets: 1
# User: vikashkaliya056 		 Name: KUMAR VIKASH 		 Number of tweets: 0
# User: s_purohit2006 		 Name: Subhash Purohit 		 Number of tweets: 0
# User: sajjadjohn393 		 Name: Sajjad 		 Number of tweets: 1
# User: SadiqAlmarzoo10 		 Name: Sadiq Almarzooq 		 Number of tweets: 0
# User: Vihit009 		 Name: Vihit 		 Number of tweets: 0
# User: lovesrk0856 		 Name: isha  muzumdar 		 Number of tweets: 0
# User: ummerfarooqnaj1 		 Name: ummer farooq najar 		 Number of tweets: 0
# User: SyaputraAndreas 		 Name: Andreas Syaputra 		 Number of tweets: 0
# User: iharshaBieber 		 Name: Harsha Bieber Jb 		 Number of tweets: 601
# User: AAFAHADFNN 		 Name: A A FAHAD 		 Number of tweets: 0
# User: muhammad7278788 		 Name: muhammad saleem 		 Number of tweets: 0
# User: sanjeetraj11221 		 Name: sajeet kumar 		 Number of tweets: 1
# User: MayuriDey5 		 Name: Mayuri Dey 		 Number of tweets: 1
# User: patel16_a 		 Name: Aarsh Patel 		 Number of tweets: 0
# User: nssr880 		 Name: Narender Sharma 		 Number of tweets: 0
# User: ahmadabbassulei 		 Name: ahmad abbas suleiman 		 Number of tweets: 52
# User: yenntyblb3 		 Name: Yenntyblb 		 Number of tweets: 0
# User: AliRazaLucky6 		 Name: Ali Raza Lucky 		 Number of tweets: 92
# User: bhanumanju23 		 Name: bhanu prakash 		 Number of tweets: 1
# User: SpsahuSs7 		 Name: satyaprakash sahu 		 Number of tweets: 0
# User: istkharalam6 		 Name: istkharalam 		 Number of tweets: 0
# User: tar_kas 		 Name: kas.tar 		 Number of tweets: 0
# User: Perumal64188160 		 Name: Perumal 		 Number of tweets: 0
# User: 5lkaL1WYeZ1W0Bi 		 Name: جاسم المغربي 		 Number of tweets: 0
# User: FYemad 		 Name: Yemad Fayed Ahmed 		 Number of tweets: 1
# User: hasibul_ras 		 Name: Md.hasibul islam ras 		 Number of tweets: 0
# User: AmitCha43904759 		 Name: Amit Chauhan 		 Number of tweets: 0
# User: Deekshaawasthi7 		 Name: Deeksha awasthi 		 Number of tweets: 0
# User: Sourav44861379 		 Name: Sourav 		 Number of tweets: 0
# User: c_dhabhai 		 Name: Chandramohan Dhabhai 		 Number of tweets: 0
# User: Rajyavardhanma2 		 Name: Rajyavardhan maurya 		 Number of tweets: 0
# User: NaveenS08825323 		 Name: Naveen Shetty 		 Number of tweets: 0
# User: Stanleypelaut78 		 Name: Stanleypelaut@gmail 		 Number of tweets: 0
# User: dwiariefhardian 		 Name: ⚡  ⚡ 		 Number of tweets: 0
# User: AleemridaShaik 		 Name: Shaik Aleem Jani 		 Number of tweets: 4
# User: ratnaheraswati1 		 Name: ratnaheraswati 		 Number of tweets: 8
# User: ShyamsundarDol1 		 Name: Shyamsundar Dolui 		 Number of tweets: 0
# User: pavansinghrock1 		 Name: pavansinghrocking@Gm 		 Number of tweets: 0
# User: DoddyRahmatP 		 Name: Doddy Rahmat Putra 		 Number of tweets: 0
# User: sonubangaram333 		 Name: L suresh 		 Number of tweets: 0
# User: vikashyadhu 		 Name: vikash yadhuvansi 		 Number of tweets: 5
# User: paharia_saurabh 		 Name: saurabh paharia 		 Number of tweets: 0
# User: abbas12345ka222 		 Name: نساني ظلعي 		 Number of tweets: 0
# User: ptryuliantii 		 Name: putri yulianti 		 Number of tweets: 0
# User: mmrhridoy0101 		 Name: Moshiur Rahman 		 Number of tweets: 0
# User: apateriya091 		 Name: Ashish Pateriya 		 Number of tweets: 1
# User: TUMMALA20 		 Name: T S NAGESWARA RAO 		 Number of tweets: 0
# User: xsqRnpjWpVupuiQ 		 Name: محمد علي 		 Number of tweets: 0
# User: elangperwira4 		 Name: elabgperwira 		 Number of tweets: 1
# User: durga_024 		 Name: Durga Prasad 		 Number of tweets: 2
# User: PunnuKatron 		 Name: Punnu Katron 		 Number of tweets: 2
# User: Bhavesh17708381 		 Name: Bhavesh Parmar 		 Number of tweets: 1
# User: xpaLcvjkNXZ0171 		 Name: احمد محمد 		 Number of tweets: 1
# User: noushadtotad 		 Name: NOUSHAD 		 Number of tweets: 0
# User: SiskaNuralfiah 		 Name: siska jessiliciuos 		 Number of tweets: 1080
# User: sachitagarwal02 		 Name: Sachit Agarwal 		 Number of tweets: 1
# User: bqe20 		 Name: bq 		 Number of tweets: 0
# User: tarash_murmu 		 Name: Tarash M. Murmu 		 Number of tweets: 0
# User: nitish1186 		 Name: nitish alok 		 Number of tweets: 0
# User: JampuKirankumar 		 Name: kirankumar 		 Number of tweets: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-80804c23b50a> in <module>()
#      22             time.sleep(15 * 60)
#      23
# ---> 24 for follower in limit_handled(tweepy.Cursor(api.followers, screen_name="iamsrk").items()):
#      25     print("User: {0} \t\t Name: {1} \t\t Number of tweets: {2}".format(follower.screen_name.encode("utf-8"),
#      26                                                                           follower.name.encode("utf-8"),
#
# <ipython-input-5-80804c23b50a> in limit_handled(cursor)
#      20             yield cursor.next()
#      21         except tweepy.RateLimitError:
# ---> 22             time.sleep(15 * 60)
#      23
#      24 for follower in limit_handled(tweepy.Cursor(api.followers, screen_name="iamsrk").items()):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Q5. Predict the sentiment of tweets by followers of ***naveen_odisha***

# %%
import csv
import re, math, collections, itertools, os
import time
import tweepy
import nltk, nltk.classify.util, nltk.metrics
from nltk.classify import NaiveBayesClassifier
from nltk.metrics import BigramAssocMeasures
from nltk.probability import FreqDist, ConditionalFreqDist
from nltk.metrics import accuracy, precision, recall

#this function takes a feature selection mechanism and returns its performance in a variety of metrics
def evaluate_features(feature_select):
	posFeaturesTrain = []
	negFeaturesTrain = []

	#breaks up the sentences into lists of individual words and appends 'pos' or 'neg' after each list
	with open("/home/abhijit/Documents/TwitterAnalysis/trainingandtestdata/training.1600000.processed.noemoticon.csv", 'r') as TrainFile:
		TrainTweets = csv.reader(TrainFile)
		for i in TrainTweets:
			if i[0]=="4":
				posWordsTrain = re.findall(r"[\w']+|[.,!?;]", i[4].rstrip())
				posWordsTrain = [feature_select(posWordsTrain), 'pos']
				posFeaturesTrain.append(posWordsTrain)
			elif i[0]=="0":
				negWordsTrain = re.findall(r"[\w']+|[.,!?;]", i[4].rstrip())
				negWordsTrain = [feature_select(negWordsTrain), 'neg']
				negFeaturesTrain.append(negWordsTrain)

	trainFeatures = posFeaturesTrain + negFeaturesTrain

#pulls follower tweets for sentiment prediction
TWITTER_CONSUMER_KEY = os.environ["TWITTER_CONSUMER_KEY"]
TWITTER_CONSUMER_SECRET = os.environ["TWITTER_CONSUMER_SECRET"]
TWITTER_ACCESS_TOKEN = os.environ["TWITTER_ACCESS_TOKEN"]
TWITTER_ACCESS_TOKEN_SECRET = os.environ["TWITTER_ACCESS_TOKEN_SECRET"]

auth = tweepy.OAuthHandler(TWITTER_CONSUMER_KEY, TWITTER_CONSUMER_SECRET)
auth.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

if(api.verify_credentials):
    print 'Sucessfully logged in'

def limit_handled(cursor):
    while True:
        try:
            yield cursor.next()
        except tweepy.RateLimitError:
            time.sleep(15 * 60)
    
	#selects the features to be used for testing
	TestTweets = []
    for follower in limit_handled(tweepy.Cursor(api.followers, screen_name="naveen_odisha").items()):
        TestTweets.append(follower.text.encode("utf-8"))
        print(TestTweets)
    
    for j in TestTweets:
        WordsTest = re.findall(r"[\w']+|[.,!?;]".j.rstrip())
		WordsTest = [feature_select(WordsTest)]
		testFeatures.append(WordsTest)
	
	#trains a Naive Bayes Classifier
	classifier = NaiveBayesClassifier.train(trainFeatures)

	#initiates referenceSets and testSets
	referenceSets = collections.defaultdict(set)
	testSets = collections.defaultdict(set)	

	#puts correctly labeled sentences in referenceSets and the predictively labeled version in testsets
	for k, (features, label) in enumerate(testFeatures):
		referenceSets[label].add(k)
		predicted = classifier.classify(features)
		testSets[predicted].add(k)	

	#prints metrics to show how well the feature selection did
	print 'train on %d instances, test on %d instances' % (len(trainFeatures), len(testFeatures))
	classifier.show_most_informative_features(10)

#creates a feature selection mechanism that uses all words
def make_full_dict(words):
	return dict([(word, True) for word in words])

#tries using all words as the feature selection mechanism
print 'using all words as features'
evaluate_features(make_full_dict)

#for status in result["statuses"]:
#    print("Tweet: {0} \n Sentiment: {1} \n".format(status["text"].encode("utf-8"), classifier.classify(getFeatures(status["text"].encode("utf-8").split()))))
# Out:
#   File "<ipython-input-4-485dbe1e7a06>", line 58
#     WordsTest = [feature_select(WordsTest)]
#     ^
# IndentationError: unexpected indent
